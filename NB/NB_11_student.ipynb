# %% [markdown]
# # NB 11: Group Model Inference

# %%
# This code will load the R packages we will use
install.packages(c("rcistats", "openintro", "emmeans", "hellodatascience"),
                 repos = c("https://inqs909.r-universe.dev", "https://cloud.r-project.org"))
library(rcistats)
library(tidyverse)
library(openintro)
library(emmeans)
library(hellodatascience)
# Out:
# Installing packages into ‘/home/isaac/R/x86_64-pc-linux-gnu-library/4.5’
# (as ‘lib’ is unspecified)
# trying URL 'https://inqs909.r-universe.dev/src/contrib/sha256-11acf4f96b9e351f559a2813af440ec718db38c89241835e47604f7b4ef1beaa'
# trying URL 'https://cloud.r-project.org/src/contrib/openintro_2.5.0.tar.gz'
# trying URL 'https://cloud.r-project.org/src/contrib/emmeans_2.0.3.tar.gz'
# trying URL 'https://cloud.r-project.org/src/contrib/hellodatascience_0.1.0.tar.gz'
# * installing *source* package ‘rcistats’ ...
# ** this is package ‘rcistats’ version ‘0.1.4’
# ** using staged installation
# ** R
# ** byte-compile and prepare package for lazy loading
# ** help
# *** installing help indices
# ** building package indices
# ** testing if installed package can be loaded from temporary location
# ** testing if installed package can be loaded from final location
# ** testing if installed package keeps a record of temporary installation path
# * DONE (rcistats)
# ...

# %% [markdown]
# In 2004, the state of North Carolina released a large data set containing information on births recorded in this state.
# This data set is useful to researchers studying the relation between habits and practices of expectant mothers and the birth of their children.
# We will work with a random sample of observations from this data set.

# %% [markdown]
# ## Part 1: Modeling Premature Infants
#
# In 2004, the state of North Carolina released a large data set (`ncbrith`) containing information on births recorded in this state. This data set is useful to researchers studying the relation between habits and practices of expectant mothers and the birth of their children. We will work with a random sample of observations from this data set.

# %% [markdown]
# ### A. Smoking Habits
#
# Let's consider how smoking habit (`habit`; predictor) affects the probability of having a premature infant (`premie`; outcome), is there an association between smoking habit and premature infant?

# %% [markdown]
# 1. Obtain descriptive statistics for `mature` and `habit`, and describe the distributions.

# %% [markdown]
# 2. Write the null and alternative hypothesis.

# %% [markdown]
# 3. Write your significant level.

# %% [markdown]
# 4. Conduct your hypothesis and obtain your p-value.

# %% [markdown]
# 5. Make a decision.

# %% [markdown]
# 6. Draw conclusions or perform post-hoc analysis, then draw conclusions.

# %% [markdown]
# ### B. Mother's Matururity Status
#
# Now consider how Mother's Maturity (`mature`; predictor) affects the likelihood of seeing a premature infant (`premie`; otucome). Is there a significant association maturity level versus premature infant?

# %% [markdown]
# 1. Obtain descriptive statistics for `mature` and `premie`, and describe the distributions.

# %% [markdown]
# 2. Write the null and alternative hypothesis.

# %% [markdown]
# 3. Write your significant level.

# %% [markdown]
# 4. Conduct your hypothesis and obtain your p-value.

# %% [markdown]
# 5. Make a decision.

# %% [markdown]
# 6. Draw conclusions or perform post-hoc analysis, then draw conclusions.

# %% [markdown]
# ## Part 2: Modelling Retail Price
#
# The USDA (US Department of Agriculture), estimated average prices for 153 commonly consumed produce from grocery stores, supermarkets, supercenters and more. The data set is called `produce_prices` and the outcome of interest is `retail_price`.

# %% [markdown]
# ### A. Price by Fruit or Vegetable
#
# Let's consider how the retail price (`retail_price`; outcome) is affected by either being a fruit or vegetable (`type`). Are there any differences in statistics based on type of food?

# %% [markdown]
# 1. Obtain descriptive statistics for `retail_price` and `type`, and describe the distributions.

# %% [markdown]
# 2. Write the null and alternative hypothesis.

# %% [markdown]
# 3. Write your significant level.

# %% [markdown]
# 4. Conduct your hypothesis and obtain your p-value.

# %% [markdown]
# 5. Make a decision.

# %% [markdown]
# 6. Draw conclusions or perform post-hoc analysis, then draw conclusions.

# %% [markdown]
# ### B. Price by Unit Type
#
# Now consider how the retail price (`retail_price`; outcome) is affected by either the pricer per pound or price per pint (`retail_price_unit`). Are there any differences in statistics based on per unit size?

# %% [markdown]
# 1. Obtain descriptive statistics for `retail_price` and `retail_price_unit`, and describe the distributions.

# %% [markdown]
# 2. Write the null and alternative hypothesis.

# %% [markdown]
# 3. Write your significant level.

# %% [markdown]
# 4. Conduct your hypothesis and obtain your p-value.

# %% [markdown]
# 5. Make a decision.

# %% [markdown]
# 6. Draw conclusions or perform post-hoc analysis, then draw conclusions.
